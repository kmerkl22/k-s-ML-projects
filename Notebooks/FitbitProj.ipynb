# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../Data/dailyActivity_merged.csv')
#edit this later for github link

# %%
data
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
data.shape
# Out:
# (940, 15)

# %%
data.Id.nunique()
# Out:
# 33

# %%
data.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
data.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
plt.scatter(data.TotalSteps,data.Calories)

# %%
pd.plotting.scatter_matrix(data.iloc[:,[14,2,3,4]]);

# %%
pd.plotting.scatter_matrix(data.iloc[:,[14,5, 6, 7]]);

# %%
pd.plotting.scatter_matrix(data.iloc[:,[14,8, 9, 10]]);

# %%
fig = plt.figure(constrained_layout=True)


for i in range(2,14):
        plt.subplot(4,4,i-1)
        plt.scatter(data.iloc[:,i],data.Calories, s=1)
        plt.xlabel(data.columns[i])
        plt.ylabel('Calories')
#     #plt.scatter(data.iloc[:,i],data.Calories)
#     fig, axs[0,0] = plt.scatter(data.iloc[:,i],data.Calories)

# %%
cols =['Id', 'TotalSteps', 'TotalDistance', 'TrackerDistance','VeryActiveMinutes', 'FairlyActiveMinutes',
              'LightlyActiveMinutes', 'Calories']

data2 = data[cols]

# %%
data2.columns
# Out:
# Index(['Id', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes',
#        'Calories'],
#       dtype='object')

# %%
data2.head()
# Out:
#            Id  TotalSteps  TotalDistance  TrackerDistance  VeryActiveMinutes  \
# 0  1503960366       13162           8.50             8.50                 25
# 1  1503960366       10735           6.97             6.97                 21
# 2  1503960366       10460           6.74             6.74                 30
# 3  1503960366        9762           6.28             6.28                 29
# 4  1503960366       12669           8.16             8.16                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  Calories
# 0                   13                   328      1985
# 1                   19                   217      1797
# 2                   11                   181      1776
# 3                   34                   209      1745
# 4                   10                   221      1863

# %%
plt.scatter(data2.TotalSteps,data2.Calories)

# %%
#data3 = data2.drop()


data3 = data2.replace(0, np.nan, inplace = True)

data2.TotalSteps.min

# Auto = pd.read_csv('Auto.data', na_value = ['?'], delim_whitespace = True)
# Auto.shape
#A uto_new = Auto.dropna()
# Auto_new.shape
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0      13162.0
# 1      10735.0
# 2      10460.0
# 3       9762.0
# 4      12669.0
#         ...
# 935    10686.0
# 936    20226.0
# 937    10733.0
# 938    21420.0
# 939     8064.0
# Name: TotalSteps, Length: 940, dtype: float64>

# %%
data2.dropna()
data2.shape
# Out:
# (940, 8)

# %%
data3 = data2[data2['TotalSteps']>100]

# %%
data3 = data3[data3['Calories']>750]
data3 = data3[data3['TotalSteps']<25000]
plt.scatter(data3.TotalSteps, data3.Calories)

# %%
data3.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  8.480000e+02    848.000000     848.000000       848.000000
# mean   4.864062e+09   8351.906840       5.987700         5.971792
# std    2.418282e+09   4486.465773       3.477876         3.458466
# min    1.503960e+09    108.000000       0.080000         0.080000
# 25%    2.320127e+09   4989.250000       3.450000         3.450000
# 50%    4.501862e+09   8094.000000       5.635000         5.635000
# 75%    6.962181e+09  11100.250000       7.912500         7.882500
# max    8.877689e+09  23629.000000      20.650000        20.650000
#
#        VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# count          525.00000           552.000000            841.000000
# mean            37.04000            22.914855            214.438763
# std             35.32278            21.444268             92.583470
# min              1.00000             1.000000              3.000000
# ...

# %%
data3.shape

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit

import numpy

data3["Calories_cat"] = pd.cut(data3["Calories"], bins = [900, 1600,  1900, 2300, 3000, np.inf], labels = ["very low", "low", "medium", "high", "very high"])

#strat_train_set, strat_test_set = train_test_split(data3, test_size=0.2, stratify=data3["Calories"])
#strat_train_set.shape, strat_test_set.shape

#labels

data3.shape
data3.head()
# Out:
#            Id  TotalSteps  TotalDistance  TrackerDistance  VeryActiveMinutes  \
# 0  1503960366     13162.0           8.50             8.50               25.0
# 1  1503960366     10735.0           6.97             6.97               21.0
# 2  1503960366     10460.0           6.74             6.74               30.0
# 3  1503960366      9762.0           6.28             6.28               29.0
# 4  1503960366     12669.0           8.16             8.16               36.0
#
#    FairlyActiveMinutes  LightlyActiveMinutes  Calories Calories_cat
# 0                 13.0                 328.0    1985.0       medium
# 1                 19.0                 217.0    1797.0          low
# 2                 11.0                 181.0    1776.0          low
# 3                 34.0                 209.0    1745.0          low
# 4                 10.0                 221.0    1863.0          low

# %%
fitbit_labels =

# %%
import sklearn 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
# extra code – computes the data for Figure 2–10

def calorie_cat_proportions(data3):
    return data3["Calories_cat"].value_counts() / len(data3)

train_set, test_set = train_test_split(data3, test_size=0.2, random_state=42)

strat_train_set, strat_test_set = train_test_split(data3, test_size=0.2, stratify=data3["Calories_cat"])

compare_props = pd.DataFrame({
    "Overall %": calorie_cat_proportions(data3),
    "Stratified %": calorie_cat_proportions(strat_test_set),
    "Random %": calorie_cat_proportions(test_set),
}).sort_index()
compare_props.index.name = "Calorie Category"
compare_props["Strat. Error %"] = (compare_props["Stratified %"] /
                                   compare_props["Overall %"] - 1)
compare_props["Rand. Error %"] = (compare_props["Random %"] /
                                  compare_props["Overall %"] - 1)
(compare_props * 100).round(2)
# Out:
#                   Overall %  Stratified %  Random %  Strat. Error %  \
# Calorie Category
# very low              11.20         11.18      9.41           -0.24
# low                   16.16         15.88     16.47           -1.69
# medium                26.30         26.47     24.12            0.66
# high                  28.54         28.82     32.35            1.00
# very high             17.81         17.65     17.65           -0.90
#
#                   Rand. Error %
# Calorie Category
# very low                 -15.99
# low                        1.95
# medium                    -8.29
# high                      13.37
# very high                 -0.90

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop("Calories_cat", axis=1, inplace=True)

# %%
strat_train_set
# Out:
#              Id  TotalSteps  TotalDistance  TrackerDistance  \
# 644  6290855005      9837.0           7.44             7.44
# 431  4388161847     10255.0           7.89             7.89
# 807  8253242879      6466.0           4.27             4.27
# 126  1927972279       980.0           0.68             0.68
# 688  6962181067     13928.0           9.55             9.55
# ..          ...         ...            ...              ...
# 480  4558609924      8940.0           5.91             5.91
# 831  8378563200     12405.0           9.84             9.84
# 416  4388161847      6580.0           5.06             5.06
# 94   1844505072      7937.0           5.25             5.25
# 928  8877689391     10930.0           8.32             8.32
#
#      VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  Calories
# 644                8.0                 95.0                 282.0    3327.0
# 431               12.0                 15.0                 241.0    2926.0
# ...

# %%
columns = ["TotalSteps", "Calories"]
CalSteps_Train = strat_train_set[columns]
CalSteps_Test = strat_test_set[columns]
# Out:
#      TotalSteps  Calories
# 435      9603.0    2899.0
# 161     11548.0    2489.0
# 684     13217.0    2173.0
# 839      8712.0    3784.0
# 902      2283.0    2067.0
# ..          ...       ...
# 825     13070.0    4092.0
# 574     12574.0    3501.0
# 650      5510.0    2613.0
# 455      5002.0    2247.0
# 608     11495.0    2651.0
#
# [170 rows x 2 columns]

# %%
fitbit = CalSteps_Train.drop("Calories", axis=1)
fitbit_labels = CalSteps_Train["Calories"].copy()

fitbit.columns
# Out:
# Index(['TotalSteps'], dtype='object')

# %%
from sklearn.linear_model import LinearRegression

target_scaler = StandardScaler()
scaled_labels = target_scaler.fit_transform(fitbit_labels.to_frame())

model = LinearRegression()
model.fit(fitbit[["TotalSteps"]], scaled_labels)

some_new_data = fitbit[["TotalSteps"]].iloc[:20]  # pretend this is new data

scaled_predictions = model.predict(some_new_data)
predictions = target_scaler.inverse_transform(scaled_predictions)

# %%
plt.scatter(fitbit["TotalSteps"].iloc[:20], predictions)

# %%
plt.scatter(fitbit["TotalSteps"].iloc[:20], CalSteps_Train["Calories"].iloc[:20])

# %%
fitbit.iloc[:5]
# Out:
#      TotalSteps
# 644      9837.0
# 431     10255.0
# 807      6466.0
# 126       980.0
# 688     13928.0

# %%
predictions
# Out:
# array([[2498.01703247],
#        [2532.38201389],
#        [2220.87743354],
#        [1769.85760566],
#        [2834.34990084]])

# %%
CalSteps_Train.head(5)
# Out:
#      TotalSteps  Calories
# 644      9837.0    3327.0
# 431     10255.0    2926.0
# 807      6466.0    1931.0
# 126       980.0    2221.0
# 688     13928.0    2174.0

# %%
fitbit.head(5)
# Out:
#      TotalSteps
# 644      9837.0
# 431     10255.0
# 807      6466.0
# 126       980.0
# 688     13928.0
